# %% [markdown]
# **<h2> Manipulando Dados em DataFrames do Pandas</h2>**

# %%
# cria um dicionário

dados = {'Estado': ['Santa Catarina','Rio de Janeiro','Tocantins', 'Bahia','Minas Gerais'],
         'Ano':[2004,2005,2006,2007,2008],
         'Taxa Desemprego':[1.5,1.7,1.6,2.4,2.7]
         }

# %%
import pandas as pd

# %%
from pandas import DataFrame

# %%
df = DataFrame(dados)

# %%
#Visualiza as 5 primeiras linhas
df.head()
# Out:
#            Estado   Ano  Taxa Desemprego
# 0  Santa Catarina  2004              1.5
# 1  Rio de Janeiro  2005              1.7
# 2       Tocantins  2006              1.6
# 3           Bahia  2007              2.4
# 4    Minas Gerais  2008              2.7

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Reorganizando as colunas

DataFrame(dados,columns=['Estado','Taxa Desemprego','Ano'])
# Out:
#            Estado  Taxa Desemprego   Ano
# 0  Santa Catarina              1.5  2004
# 1  Rio de Janeiro              1.7  2005
# 2       Tocantins              1.6  2006
# 3           Bahia              2.4  2007
# 4    Minas Gerais              2.7  2008

# %%
#Criando outro dataframe com os mesmos dados anteriores mas adicionando uma coluna

df2 = DataFrame(dados,columns=['Estado','Taxa Desemprego','Taxa Crescimento','Ano'],
                               index = ['estado1','estado2','estado3','estado4','estado5'])

# %%
df2
# Out:
#                  Estado  Taxa Desemprego Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5              NaN  2004
# estado2  Rio de Janeiro              1.7              NaN  2005
# estado3       Tocantins              1.6              NaN  2006
# estado4           Bahia              2.4              NaN  2007
# estado5    Minas Gerais              2.7              NaN  2008

# %%
df2.values
# Out:
# array([['Santa Catarina', 1.5, nan, 2004],
#        ['Rio de Janeiro', 1.7, nan, 2005],
#        ['Tocantins', 1.6, nan, 2006],
#        ['Bahia', 2.4, nan, 2007],
#        ['Minas Gerais', 2.7, nan, 2008]], dtype=object)

# %%
df2.dtypes
# Out:
# Estado               object
# Taxa Desemprego     float64
# Taxa Crescimento     object
# Ano                   int64
# dtype: object

# %%
df2.columns
# Out:
# Index(['Estado', 'Taxa Desemprego', 'Taxa Crescimento', 'Ano'], dtype='object')

# %%
# Imprimindo apenas uma coluna do DataFrame
df2['Estado']
# Out:
# estado1    Santa Catarina
# estado2    Rio de Janeiro
# estado3         Tocantins
# estado4             Bahia
# estado5      Minas Gerais
# Name: Estado, dtype: object

# %%
#Imprimindo apenas duas colunas do DataFrame
df2[['Taxa Desemprego','Ano']]
# Out:
#          Taxa Desemprego   Ano
# estado1              1.5  2004
# estado2              1.7  2005
# estado3              1.6  2006
# estado4              2.4  2007
# estado5              2.7  2008

# %%
#Filtrando pelo índice

df2.filter(items=['estado3'],axis = 0)
# Out:
#             Estado  Taxa Desemprego Taxa Crescimento   Ano
# estado3  Tocantins              1.6              NaN  2006

# %% [markdown]
# **<h2> Usando NumPy e Pandas para manipulação de  Dados</h2>**

# %%
df2.head()
# Out:
#                  Estado  Taxa Desemprego Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5              NaN  2004
# estado2  Rio de Janeiro              1.7              NaN  2005
# estado3       Tocantins              1.6              NaN  2006
# estado4           Bahia              2.4              NaN  2007
# estado5    Minas Gerais              2.7              NaN  2008

# %%
#Resumo estatístico do DataFrame
df2.describe()
# Out:
#        Taxa Desemprego          Ano
# count         5.000000     5.000000
# mean          1.980000  2006.000000
# std           0.535724     1.581139
# min           1.500000  2004.000000
# 25%           1.600000  2005.000000
# 50%           1.700000  2006.000000
# 75%           2.400000  2007.000000
# max           2.700000  2008.000000

# %%
#Verifica se tem valor NaN
df2.isna()
# Out:
#          Estado  Taxa Desemprego  Taxa Crescimento    Ano
# estado1   False            False              True  False
# estado2   False            False              True  False
# estado3   False            False              True  False
# estado4   False            False              True  False
# estado5   False            False              True  False

# %%
df2['Taxa Crescimento'].isna()
# Out:
# estado1    True
# estado2    True
# estado3    True
# estado4    True
# estado5    True
# Name: Taxa Crescimento, dtype: bool

# %%
import numpy as np

# %%
df2['Taxa Crescimento'] = np.arange(5.)

# %%
df2
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5               0.0  2004
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3       Tocantins              1.6               2.0  2006
# estado4           Bahia              2.4               3.0  2007
# estado5    Minas Gerais              2.7               4.0  2008

# %%
df2['Taxa Crescimento'].isna()
# Out:
# estado1    False
# estado2    False
# estado3    False
# estado4    False
# estado5    False
# Name: Taxa Crescimento, dtype: bool

# %%
df2.describe()
# Out:
#        Taxa Desemprego  Taxa Crescimento          Ano
# count         5.000000          5.000000     5.000000
# mean          1.980000          2.000000  2006.000000
# std           0.535724          1.581139     1.581139
# min           1.500000          0.000000  2004.000000
# 25%           1.600000          1.000000  2005.000000
# 50%           1.700000          2.000000  2006.000000
# 75%           2.400000          3.000000  2007.000000
# max           2.700000          4.000000  2008.000000

# %% [markdown]
# **<h2> Slicing de DataFrame do Pandas</h2>**

# %%
df2
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5               0.0  2004
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3       Tocantins              1.6               2.0  2006
# estado4           Bahia              2.4               3.0  2007
# estado5    Minas Gerais              2.7               4.0  2008

# %%
df2['estado2':'estado4']
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3       Tocantins              1.6               2.0  2006
# estado4           Bahia              2.4               3.0  2007

# %%
df2[df2['Taxa Desemprego']< 2]
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5               0.0  2004
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3       Tocantins              1.6               2.0  2006

# %%
df2[['Estado','Taxa Crescimento']]
# Out:
#                  Estado  Taxa Crescimento
# estado1  Santa Catarina               0.0
# estado2  Rio de Janeiro               1.0
# estado3       Tocantins               2.0
# estado4           Bahia               3.0
# estado5    Minas Gerais               4.0

# %%
df2[['Estado','Taxa Crescimento','Ano']]
# Out:
#                  Estado  Taxa Crescimento   Ano
# estado1  Santa Catarina               0.0  2004
# estado2  Rio de Janeiro               1.0  2005
# estado3       Tocantins               2.0  2006
# estado4           Bahia               3.0  2007
# estado5    Minas Gerais               4.0  2008

# %% [markdown]
# **<h2> Preenchendo Valores Ausentes em DataFrames do Pandas</h2>**

# %% [markdown]
# A função fillna() é usada para preencher os valores ausentes. A função oferece muitas opções. Podemos usar um valor específico, uma função agregada(por exemplo, média) ou o valore anterior ou seguinte.
#
# Para esse exemplo usaremos a moda, a estatística que representa o valor que aparece mais vezes em uma variável.

# %%
# Primeiro importamos um dataset
dsa_df = pd.read_csv('dataset.csv')

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %%
dsa_df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      2
# dtype: int64

# %%
# Extraímos a moda da coluna Quantity
moda = dsa_df['Quantidade'].value_counts().index[0]

# %%
moda
# Out:
# 3.0

# %%
# E por fim preenchemos os valores NA com a moda
dsa_df['Quantidade'].fillna(value=moda,inplace=True)

#inplace = True é como se fosse pra salvar o resultado dentro do dataframe original

# %%
dsa_df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      0
# dtype: int64

# %% [markdown]
# **<h2> Query(Consulta) de Dados no DataFrame do Pandas</h2>**
#
# Com o Pandas criamos dataframes, que são essencialmente tabelas.Como tal, podemos fazer consultas, ou simplesmente queries. E para isso usamos o método query(). Veja o exemplo abaixo:

# %%
#Checamos os valores mínimo e máximo da coluna Valor_Venda
dsa_df['Valor_Venda'].describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# O intervalo de Vendas (Valor_Venda) é de 0.44 a 22638. Vamos fazer uma consulta e retornar todas as vendas dentro de um range de valores. Fazemos isso com a instrução abaixo

# %%
#Geramos um novo dataframe apenas com o intervalo proposto
df2 = dsa_df.query('229 < Valor_Venda < 10000')

# %%
df2
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 1     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 7     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# ...              ...         ...        ...          ...            ...
# 9973  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9976  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9979  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9991  CA-2017-121258  2017-02-26   DB-13060     Consumer  United States
# 9993  CA-2017-119914  2017-05-04   CC-12220     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 0     South  FUR-BO-10001798        Furniture
# ...

# %%
df2['Valor_Venda'].describe()
# Out:
# count    2357.000000
# mean      766.679142
# std       856.315136
# min       229.544000
# 25%       323.100000
# 50%       490.320000
# 75%       859.200000
# max      9892.740000
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# **<h2>Verificando a Ocorrência de Diversos Valores em uma Coluna</h2>**

# %% [markdown]
# Em nosso conjunto de dados de exemplo, temos a coluna Quantidade que representa a qtde de itens vendidos em cada uma das vendas. Imagine que precisamos saber em quais vendas foram vendidos 5,7,9 ou 11 itens.
#
# Como aplicaríamos esse filtro ao nosso dataframe?
#
# Fácil. O Pandas oferece o método isin() para checar diversos valores em uma coluna. Quem conhece SQL já deve ter percebido que é o método IN em SQL. ex

# %%
dsa_df.shape
# Out:
# (9994, 11)

# %%
# Então aplicamos o filtro

dsa_df[dsa_df['Quantidade'].isin([5,7,9,11])]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14    US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# ...              ...         ...        ...          ...            ...
# 9974  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9977  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9981  CA-2017-163566  2017-08-03   TB-21055     Consumer  United States
# 9982  US-2016-157728  2016-09-22   RC-19960     Consumer  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
#
#        Regiao       ID_Produto        Categoria  \
# 3       South  FUR-TA-10000577        Furniture
# ...

# %% [markdown]
# Na instrução acima estamos filtrando o dataframe df, retornando as linhas onde a coluna Quantidade for igual aos valores 5,7,9 ou 11. Passamos uma lista de valores como argumento para o método isin()
#
# Vamos deixar um pouco mais divertido. Vamos retornar somente 10 linhas, não 2128:

# %%
dsa_df[dsa_df['Quantidade'].isin([5,7,9,11])].shape
# Out:
# (2128, 11)

# %%
dsa_df[dsa_df['Quantidade'].isin([5,7,9,11])][:10]
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3   US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10  CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14  US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 21  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 22  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 27  US-2015-150630  2015-09-17   TB-21520     Consumer  United States
# 35  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
# 36  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
#
#      Regiao       ID_Produto        Categoria  \
# 3     South  FUR-TA-10000577        Furniture
# 5      West  FUR-FU-10001487        Furniture
# 9      West  OFF-AP-10002892  Office Supplies
# ...

# %% [markdown]
# **<h2> Operadores Lógicos para Manipulação de Dados com Pandas</h2>**

# %%
# Filtrando as vendas que ocorreram para o segmento de home office e na região South
dsa_df[ (dsa_df['Segmento'] == 'Home Office') & (dsa_df['Regiao']=='South')].head()
# Out:
#           ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais Regiao  \
# 182  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 183  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 184  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 231  US-2017-100930  2017-04-07   CS-12400  Home Office  United States  South
# 232  US-2017-100930  2017-04-07   CS-12400  Home Office  United States  South
#
#           ID_Produto   Categoria  \
# 182  TEC-PH-10003273  Technology
# 183  TEC-PH-10004896  Technology
# 184  TEC-AC-10002345  Technology
# 231  FUR-TA-10001705   Furniture
# 232  FUR-TA-10003473   Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 182                                      AT&T TR1909W     503.9600         4.0
# 183                        Nokia Lumia 521 (T-Mobile)     149.9500         5.0
# ...

# %%
# Usando operador OR
dsa_df[(dsa_df['Segmento'] == 'Home Office') | (dsa_df['Regiao']=='South')]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 1     CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 4     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 12    CA-2017-114412  2017-04-15   AA-10480     Consumer  United States
# ...              ...         ...        ...          ...            ...
# 9979  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9980  US-2015-151435  2015-09-06   SW-20455     Consumer  United States
# 9987  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9989  CA-2014-110422  2014-01-21   TB-21400     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 0     South  FUR-BO-10001798        Furniture
# ...

# %%
dsa_df[(dsa_df['Segmento'] == 'Home Office') | (dsa_df['Regiao']=='South')].tail()
#tail visualiza a parte final do dataframe
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9979  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9980  US-2015-151435  2015-09-06   SW-20455     Consumer  United States
# 9987  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9989  CA-2014-110422  2014-01-21   TB-21400     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 9979   West  OFF-BI-10002026  Office Supplies
# 9980  South  FUR-TA-10001029        Furniture
# 9987  South  TEC-AC-10001539       Technology
# 9988  South  TEC-PH-10004006       Technology
# 9989  South  FUR-FU-10001889        Furniture
#
#                                            Nome_Produto  Valor_Venda  \
# 9979                  Ibico Recycled Linen-Style Covers      437.472
# 9980                         KI Adjustable-Height Table       85.980
# ...

# %%
dsa_df[(dsa_df['Segmento'] != 'Home Office') & (dsa_df['Regiao']!='South')].sample(5)
#sample retorna uma amostra de 5 valores
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 7593  CA-2016-158778  2016-09-05   DB-13210   Consumer  United States   East
# 4198  US-2016-161683  2016-12-03   CJ-12010   Consumer  United States   East
# 5579  CA-2017-137498  2017-09-09   LC-17050   Consumer  United States   West
# 8041  CA-2017-121489  2017-08-21   CM-11815  Corporate  United States   West
# 8884  CA-2014-107398  2014-08-25   BS-11590  Corporate  United States   East
#
#            ID_Produto        Categoria  \
# 7593  FUR-CH-10000309        Furniture
# 4198  OFF-BI-10001072  Office Supplies
# 5579  FUR-CH-10003833        Furniture
# 8041  TEC-AC-10000682       Technology
# 8884  OFF-BI-10001982  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 7593                    Global Comet Stacking Arm Chair      887.271
# 4198  GBC Clear Cover, 8-1/2 x 11, unpunched, 25 cov...       18.192
# ...

# %% [markdown]
# **<h2> Agrupamento de Dados em DataFrames com Group By</h2>**

# %% [markdown]
# A função Pandas Groupby é uma função versátil e fácil de usar que ajuda a obter uma visão geral dos dados. Isso torna mais fácil explorar o conjunto de dados e revelar os relacionamentos entre as variáveis.
#
# O código a seguir irá agrupar as linhas com base nas combinações Segmento/Regiao/Valor_Venda e nos dará a taxa média de vendas de cada grupo

# %%
# Aplicamos o group by
dsa_df[['Segmento','Regiao','Valor_Venda']].groupby(['Segmento','Regiao']).mean()
# Out:
#                      Valor_Venda
# Segmento    Regiao
# Consumer    Central   207.946728
#             East      238.875539
#             South     233.390180
#             West      217.033955
# Corporate   Central   234.763466
#             East      228.516929
#             South     238.992025
#             West      235.265911
# Home Office Central   208.248046
#             East      253.911805
#             South     272.996329
#             West      239.442692

# %% [markdown]
# Na instrução acima primeiro filtramos os dados extraindo 3 colunas: [Segumento, Regiao, Valor_venda]. Na sequência, agrupamos por duas colunas:[Segmento,Regiao]. E então calculamos a média para a coluna que ficou fora do group by, nesse caso a coluna Valor_Venda

# %% [markdown]
# **<h2> Agregação Múltipla com GroupBy</ha>**

# %% [markdown]
# Vamos explorar mais a função groupby() pois temos diversas formas de sumarização dos dados de forma mais simples. No exemplo abaixo, uniremos a função groupby() com a função agg() para realizar agregação múltipla.

# %%
#Aplicamos o group by
dsa_df[['Segmento','Regiao','Valor_Venda']].groupby(['Segmento','Regiao']).agg(['mean','std','count'])
# Out:
#                     Valor_Venda
#                            mean          std count
# Segmento    Regiao
# Consumer    Central  207.946728   587.906523  1212
#             East     238.875539   633.371169  1469
#             South    233.390180   559.346824   838
#             West     217.033955   551.997547  1672
# Corporate   Central  234.763466   818.947521   673
#             East     228.516929   530.001654   877
#             South    238.992025   586.176947   510
#             West     235.265911   471.288764   960
# Home Office Central  208.248046   371.009180   438
#             East     253.911805   722.777318   502
#             South    272.996329  1404.798466   272
#             West     239.442692   529.242737   571

# %% [markdown]
# Na instrução acima primeiro filtramos os dados extraindo 3 colunas:[Segmento, Regiao, Valor_Venda]. Na sequência, agrupamos por duas colunas:[Segmento,Regiao]. E então agregamos os dados calculando a média, o desvio padrão e contagem de elementos para a coluna que ficou de fora do group by, no caso a coluna Valor_Venda.
#
# A função agg() recebe como argumento uma lista de funções para agregação.

# %% [markdown]
# **<h2> Filtrando DataFrame do Pandas com Base em Strings</h2>**

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
# Filtramos o dataframe pela coluna Segmento com valores que iniciam com as letras 'Con'
dsa_df[dsa_df['Segmento'].str.startswith('Con')].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
#Filtramos o dataframe pela coluna Segmento com valores que terminam com as letras 'mer'
dsa_df[dsa_df['Segmento'].str.endswith('mer')].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %% [markdown]
# As funções startswith() e endswith() são muito úteis quando for necessário filtrar strings por caracteres que apareçam no começo e/ou final

# %% [markdown]
# **<h2> Split de Strings em DataFrames do Pandas</h2>**

# %% [markdown]
# Com pandas podemos realizar diversas tarefas de split de strings dividindo uma coluna ou extraindo elementos do nosso interesse

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
dsa_df['ID_Pedido'].head()
# Out:
# 0    CA-2016-152156
# 1    CA-2016-152156
# 2    CA-2016-138688
# 3    US-2015-108966
# 4    US-2015-108966
# Name: ID_Pedido, dtype: object

# %%
dsa_df['ID_Pedido'].str.split('-')
# Out:
# 0       [CA, 2016, 152156]
# 1       [CA, 2016, 152156]
# 2       [CA, 2016, 138688]
# 3       [US, 2015, 108966]
# 4       [US, 2015, 108966]
#                ...
# 9989    [CA, 2014, 110422]
# 9990    [CA, 2017, 121258]
# 9991    [CA, 2017, 121258]
# 9992    [CA, 2017, 121258]
# 9993    [CA, 2017, 119914]
# Name: ID_Pedido, Length: 9994, dtype: object

# %%
dsa_df['ID_Pedido'].str.split('-').str[1].head()
# Out:
# 0    2016
# 1    2016
# 2    2016
# 3    2015
# 4    2015
# Name: ID_Pedido, dtype: object

# %%
#Fazemos o split da coluna e extraímos o item na posição 2 (índice 1)
dsa_df['Ano'] = dsa_df['ID_Pedido'].str.split('-').str[1]

# %%
# Então conferimos a nova coluna criada
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %% [markdown]
# **<h2> Strip de Strings em DataFrames do Pandas</h2>**
#
# O split divide a string. O strip remove caracteres da string.

# %%
dsa_df.head(3)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase       261.96         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...       731.94         3.0
# 2  Self-Adhesive Address Labels for Typewriters b...        14.62         2.0
#
#     Ano
# 0  2016
# 1  2016
# 2  2016

# %%
dsa_df['Data_Pedido'].head(3)
# Out:
# 0    2016-11-08
# 1    2016-11-08
# 2    2016-06-12
# Name: Data_Pedido, dtype: object

# %% [markdown]
# A coluna 'Data_Pedido' é a data de envio do produto no formato YYYY-MM-DD. Imagine que seja necessário deixar o ano apenas com 2 dígitos sem alterar o tipo da variável. Fazemos isso com a função lstrip(), ou seja, left strip.

# %%
#Vamos remover os dígitos 2 e 0 á esquerda do valor da variável 'Data_Pedido'
dsa_df['Data_Pedido'].str.lstrip('20')
# Out:
# 0       16-11-08
# 1       16-11-08
# 2       16-06-12
# 3       15-10-11
# 4       15-10-11
#           ...
# 9989    14-01-21
# 9990    17-02-26
# 9991    17-02-26
# 9992    17-02-26
# 9993    17-05-04
# Name: Data_Pedido, Length: 9994, dtype: object

# %% [markdown]
# Como não usamos o inplace = True, a mudança é somente na memória e não altera o dataframe. Podemos usar rstrip() e strip() com diferentes variações de strip de strings

# %% [markdown]
# **<h2> Replace de Strings em DataFrames do Pandas</h2>**
#
# Se for necessário substituir caracteres dentro de uma string o Pandas oferece uma função (replace) para isso também.

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
#Substituímos os caracteres CG por AX na coluna 'ID_Cliente'
dsa_df['ID_Cliente'] = dsa_df['ID_Cliente'].str.replace('CG','AX')

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...
