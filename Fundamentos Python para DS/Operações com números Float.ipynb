# %% [markdown]
# **Operações com números Float**

# %%
3.1+6.4
# Out:
# 9.5

# %%
4 + 4.0
# Out:
# 8.0

# %%
# Resultado é um número float
4 / 2
# Out:
# 2.0

# %%
#Resultado é um numero inteiro

4 // 2
# Out:
# 2

# %% [markdown]
# <h1> Conversão </h1>

# %%
float(9)
# Out:
# 9.0

# %%
int(6.0)
# Out:
# 6

# %%
int(6.5)
# Out:
# 6

# %%
int(6.6)
# Out:
# 6

# %% [markdown]
# **<h1>Funções abs, round e pow</h1>**

# %%
#abs - valor absoluto
abs(-8)
# Out:
# 8

# %%
#abs - valor absoluto
abs(8)
# Out:
# 8

# %%
#round - retorna o valor com 2 casas decimais ou mais
round(3.14131922, 2)
# Out:
# 3.14

# %%
#potencia
pow(4,2)
# Out:
# 16

# %%
#potencia
pow(5,3)
# Out:
# 125
